# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df = pd.read_csv('../datasets/clustering_results/karateOutput_community.csv')
del df['Unnamed: 0']
df = df.set_index(['embedding method','clustering method','dimension'])


nb_kmeans = df.loc['../datasets/karate_sparse_nb.txt'].loc['kmeans']
nb_ag = df.loc['../datasets/karate_sparse_nb.txt'].loc['agglomerative']
nb_sp = df.loc['../datasets/karate_sparse_nb.txt'].loc[['spectral'],['modularity']]
#.loc['kmeans']
#print nb_kmeans.describe()
nb_sp.plot()
nb_ag.plot()
plt.show()

'''
plt.figure(dpi=100)

plt.plot(nb_kmeans.index,nb_kmeans.iloc[:,0],label="NOBE-Kmeans",linewidth=2.5)
plt.plot(nb_kmeans.index,nb_ag.iloc[:,0],label="NOBE-SP",linewidth=2.5)
plt.plot(nb_kmeans.index,nb_sp.iloc[:,0],color='blue',label="NOBE-AG",linewidth=2.5)

plt.ylabel("Modularity")
plt.xlabel("Dimensions")
plt.xlim(1,100)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()
'''
# Out:
# '\nplt.figure(dpi=100)\n\nplt.plot(nb_kmeans.index,nb_kmeans.iloc[:,0],label="NOBE-Kmeans",linewidth=2.5)\nplt.plot(nb_kmeans.index,nb_ag.iloc[:,0],label="NOBE-SP",linewidth=2.5)\nplt.plot(nb_kmeans.index,nb_sp.iloc[:,0],color=\'blue\',label="NOBE-AG",linewidth=2.5)\n\nplt.ylabel("Modularity")\nplt.xlabel("Dimensions")\nplt.xlim(1,100)\nplt.legend(loc=\'upper right\')\nplt.tight_layout()\nplt.show()\n'
